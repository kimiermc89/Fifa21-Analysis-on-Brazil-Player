# %% [markdown]
# Hi all, welcome back to my notebook
#
# This notebook will story to you about Fifa 21 Analysis
#
# What we can find and what we can achieve from this dataset will be determined inside this notebook.
#
# Stay tuned and enjoy my story telling.
#
# They will be a lot of story and insigts, i'm sure we can get from this notebook

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
fifa21_filepath = "../input/fifa-21-complete-player-dataset/fifa21_male2.csv"

# Read the file into a variable bank_data
fifa21_data = pd.read_csv(fifa21_filepath)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fifa21_data.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png  ...
#
#      CDM    RDM    RWB     LB   LCB    CB   RCB     RB    GK Gender
# ...

# %%
fifa21_data.tail()
# Out:
#            ID             Name  Age  OVA         Nationality           Club  \
# 17120  259088       A. Medioub   22   64              France     CD Tondela
# 17121  259090       W. Rickard   18   56               Wales        Burnley
# 17122  259091       C. Barrett   18   56             England        Burnley
# 17123  259101   J. Gazibegović   20   62  Bosnia Herzegovina  SK Sturm Graz
# 17124  259105  Pablo Rodríguez   18   59               Spain          Lecce
#
#        BOV   BP Position                                       Player Photo  \
# 17120   66   CB       CB  https://cdn.sofifa.com/players/259/088/20_120.png
# 17121   58  CAM   CAM CM  https://cdn.sofifa.com/players/259/090/20_120.png
# 17122   56   RB       RB  https://cdn.sofifa.com/players/259/091/20_120.png
# 17123   62   RB    RB LB  https://cdn.sofifa.com/players/259/101/20_120.png
# 17124   61   ST       ST  https://cdn.sofifa.com/players/259/105/20_120.png
#
# ...

# %%
#now we want to sort player age
#start from youngest till oldest

fifa21_sort_age = fifa21_data.sort_values('Age')
fifa21_sort_age
# Out:
#            ID                 Name  Age  OVA          Nationality  \
# 13850  247025         T. Gulliksen   16   51               Norway
# 15594  254246            D. Rivera   16   61        United States
# 12675  243491       César Gelabert   16   57                Spain
# 13280  245143            J. Crilly   16   49  Republic of Ireland
# 15374  253403  R. Borges Rodrigues   16   49            Australia
# ...       ...                  ...  ...  ...                  ...
# 548    143743         F. Mondragón   42   72             Colombia
# 5062   208927         H. Sulaimani   43   64         Saudi Arabia
# 1072   169108            L. Butrón   43   64                 Peru
# 277     53985             S. Royce   47   48              England
# 15737  254704             K. Miura   53   59                Japan
#
#                          Club  BOV   BP   Position  \
# 13850         Strømsgodset IF   53  CAM         CM
# 15594  New England Revolution   61   LW         LW
# ...

# %% [markdown]
# So from the data we can see that youngest one will be "T. Gulliksen" from Norway.
#
# He is currently 16 years old and played for Strømsgodset IF in Norway. :)
#
# Another things, from the data we can know also the oldest player that still play as profesional player is a "K.Miura".
#
# He is currently 53 years old and play for Yokohama FC from Japan.
#
# This is very unexpected because his age already half of century and still play professional football.

# %%
#shape of the data
#what is it looks like

fifa21_sort_age.shape
# Out:
# (17125, 107)

# %%
#what columns do we have inside
fifa21_sort_age.columns
# Out:
# Index(['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP',
#        'Position', 'Player Photo',
#        ...
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'Gender'],
#       dtype='object', length=107)

# %%
#we want to analyst player based on age and OVA(rating)

fifa21_age_vs_OVA = fifa21_sort_age.loc[:2,['Age', 'OVA']]
fifa21_age_vs_OVA
# Out:
#        Age  OVA
# 13850   16   51
# 15594   16   61
# 12675   16   57
# 13280   16   49
# 15374   16   49
# ...    ...  ...
# 345     33   66
# 900     33   74
# 885     33   84
# 882     33   65
# 2       33   71
#
# [15557 rows x 2 columns]

# %% [markdown]
# Now we want to see how age will effect rating of player.
#
# Some people say that 25-28 is age of peak average football player in the world.
#
# We might prove them right or wrong once we confirm it with our insigts after this.
#
# Lets find out and see whether they are right or wrong.

# %%
plt.plot(fifa21_age_vs_OVA)

# %% [markdown]
# Very hard to see guys. That means football player rating cannot be determine by age.
#
# We will find another solution to find it.
#
# Lets do it.

# %%
 fifa21_age_vs_OVA
# Out:
#        Age  OVA
# 13850   16   51
# 15594   16   61
# 12675   16   57
# 13280   16   49
# 15374   16   49
# ...    ...  ...
# 345     33   66
# 900     33   74
# 885     33   84
# 882     33   65
# 2       33   71
#
# [15557 rows x 2 columns]

# %%
plt.figure(figsize=(16,6))

sns.lineplot(data=fifa21_age_vs_OVA , x="Age", y="OVA")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='OVA'>

# %% [markdown]
# As you can see from the data set rating of the player gradually go up similar to the age but when it reach 27 years old we can see a line become more flat and that means most of the player already reach their peak .

# %%
fifa21_data.loc[(fifa21_data['Name'] == "Cristiano Ronaldo")]
# Out:
#         ID               Name  Age  OVA Nationality      Club  BOV  BP  \
# 142  20801  Cristiano Ronaldo   35   92    Portugal  Juventus   92  ST
#
#     Position                                       Player Photo  ...   CDM  \
# 142    ST LW  https://cdn.sofifa.com/players/020/801/20_120.png  ...  61+3
#
#       RDM   RWB    LB   LCB    CB   RCB    RB    GK Gender
# 142  61+3  65+3  61+3  54+3  54+3  54+3  61+3  20+3   Male
#
# [1 rows x 107 columns]

# %% [markdown]
# I find interesting information regarding our beloved player. In the age of 35, his rating still more than 90 and still in a good shape compare to other player that have same age with him.

# %%
fifa21_data.loc[(fifa21_data['Age'] == 35 )]
# Out:
#            ID           Name  Age  OVA          Nationality  \
# 8         244  G. Neville  B   35   76              England
# 10        249     P. Neville   35   74              England
# 12        330       R. Keane   35   80  Republic of Ireland
# 13        388    S. Campbell   35   75              England
# 27       1183   F. Cannavaro   35   82                Italy
# ...       ...            ...  ...  ...                  ...
# 15589  254233   H. Matamoros   35   63              Ecuador
# 15627  254359       F. Acuña   35   64             Paraguay
# 15639  254401       R. Farro   35   62                 Peru
# 15690  254584      D. Valdés   35   62            Venezuela
# 15871  255127  A. Liebeskind   35   61            Venezuela
#
#                         Club  BOV   BP   Position  \
# 8          Manchester United   78   CB  RB CB RWB
# 10                   Everton   75   CB  CDM CM RB
# 12                 LA Galaxy   81   CF         ST
# ...

# %%
fifa21_35 = fifa21_data.loc[(fifa21_data['Age'] == 35 )]

import numpy as np

fifa21_35 = np.mean(fifa21_35["OVA"])

fifa21_35
# Out:
# 71.44274809160305

# %% [markdown]
# Average rating of player at age 35 is 71.44 but Cristiano Ronaldo prove that he is Superman because his rating is 92.
#
# That means Cristiano still have a power of 25 years old people and can play for maybe another 5 years.

# %% [markdown]
# Everyone know that Brazil is a country that love football very much.
#
# We would like to analyst whether Brazil produce a lot of good rating footballer or not.
#
# I believe Brazil will produce a lot of good rating footballer.
#
# Good rating footballer means OVA > 80

# %%
fifa21_data.loc[(fifa21_data['Nationality'] == 'Brazil' )]
# Out:
#            ID               Name  Age  OVA Nationality                  Club  \
# 17        670               Zulu   26   66      Brazil       Pohang Steelers
# 21       1040     Roberto Carlos   38   79      Brazil  FC Anzhi Makhachkala
# 52       3467               Yuri   37   71      Brazil       SD Ponferradina
# 56       3712               Dida   39   75      Brazil         Internacional
# 62       5003               Cafu   37   83      Brazil                 Milan
# ...       ...                ...  ...  ...         ...                   ...
# 16945  258648     Carlos Augusto   21   66      Brazil              AC Monza
# 17006  258783  Guilherme Mantuan   22   65      Brazil        Gil Vicente FC
# 17047  258889             Nathan   18   63      Brazil           Boavista FC
# 17078  258951         Casagrande   21   65      Brazil       Portimonense SC
# 17113  259075          Yan Couto   18   64      Brazil             Girona FC
#
# ...

# %% [markdown]
# We have 857 players from Brazil.
#
# So using this number we will calculate average rating of Brazil player and how many player have rating > 80.

# %%
fifa_brazil = fifa21_data.loc[(fifa21_data['Nationality'] == 'Brazil' )]
fifa_brazil80 = fifa_brazil.loc[(fifa_brazil['OVA']>80)]

# %%
fifa_brazil80
# Out:
#            ID              Name  Age  OVA Nationality  \
# 62       5003              Cafu   37   83      Brazil
# 150     23330         M. Bordon   33   82      Brazil
# 401    135507       Fernandinho   35   84      Brazil
# 402    135567            Nilmar   26   83      Brazil
# 568    146530        Dani Alves   35   82      Brazil
# 909    164169       Filipe Luís   32   85      Brazil
# 910    164240      Thiago Silva   35   85      Brazil
# 969    165580       Diego Alves   31   82      Brazil
# 1077   169195    Renato Augusto   32   83      Brazil
# 1350   176266       Lucas Leiva   33   84      Brazil
# 1382   176676           Marcelo   32   83      Brazil
# 1390   176769             Jonas   34   82      Brazil
# 1644   180403           Willian   31   82      Brazil
# 1925   184134          Fernando   32   83      Brazil
# 2215   187961          Paulinho   31   83      Brazil
# 2238   188152             Oscar   28   83      Brazil
# ...

# %% [markdown]
# Out of 857 player, we have 56 players from Brazil that have OVA > 80
#
# Now we want to see how age effect rating for Brazil player.

# %%
fifa_brazil80.sort_values('Age')
# Out:
#            ID              Name  Age  OVA Nationality  \
# 8913   230258  Rosberto Dourado   20   81      Brazil
# 8950   230347    Welington Dano   20   81      Brazil
# 7281   222737            Malcom   21   82      Brazil
# 14656  251573        Renan Lodi   22   81      Brazil
# 5775   212823   Gabriel Barbosa   22   81      Brazil
# 9731   233419          Raphinha   23   81      Brazil
# 9059   230658            Arthur   23   84      Brazil
# 9061   230666     Gabriel Jesus   23   83      Brazil
# 9370   231943       Richarlison   23   81      Brazil
# 8894   230225    Juiano Mestres   24   81      Brazil
# 8968   230384     Nuno Padrenda   24   81      Brazil
# 7277   222716           Everton   24   81      Brazil
# 4868   207865        Marquinhos   26   85      Brazil
# 402    135567            Nilmar   26   83      Brazil
# 5136   209499           Fabinho   26   87      Brazil
# 5256   210257           Ederson   26   88      Brazil
# ...

# %%
plt.figure(figsize=(16,6))

sns.lineplot(data=fifa_brazil80, x="Age", y="OVA")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='OVA'>

# %% [markdown]
# Graph for Brazil player looks very interesting if we compare to graph of total player.
#
# Brazil player intend to have peak on age 23 up to 27 and they always go down till age 30 but they intend to pick up back their rating after age 31.
#
# This is interesting and i never thought that Brazil player will have this kind of graph.

# %%
fifa21_data.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png  ...
#
#      CDM    RDM    RWB     LB   LCB    CB   RCB     RB    GK Gender
# ...

# %%
fifa_brazil80 = fifa_brazil.loc[(fifa_brazil['OVA'] > 80)]
fifa_brazil_ST = fifa_brazil80.loc[(fifa_brazil80['Position'] == "ST")]

# %%
fifa_brazil_ST
# Out:
#           ID           Name  Age  OVA Nationality             Club  BOV  BP  \
# 1390  176769          Jonas   34   82      Brazil       SL Benfica   81  CF
# 8990  230430    Oswaldinato   28   81      Brazil           Brazil   81  ST
# 9061  230666  Gabriel Jesus   23   83      Brazil  Manchester City   85  ST
#
#      Position                                       Player Photo  ...   CDM  \
# 1390       ST  https://cdn.sofifa.com/players/176/769/19_120.png  ...  59+2
# 8990       ST  https://cdn.sofifa.com/players/230/430/20_120.png  ...  48+2
# 9061       ST  https://cdn.sofifa.com/players/230/666/20_120.png  ...  60+2
#
#        RDM   RWB    LB   LCB    CB   RCB    RB    GK Gender
# 1390  59+2  58+2  54+2  51+2  51+2  51+2  54+2  17+2   Male
# 8990  48+2  51+2  48+2  43+2  43+2  43+2  48+2  17+2   Male
# 9061  60+2  62+2  59+2  54+2  54+2  54+2  59+2  19+2   Male
#
# [3 rows x 107 columns]

# %% [markdown]
# Unfortunately Brazil dont have a lot of Striker.
#
# That means if you are working with football team, dont choose player from Brazil as your striker.

# %%
fifa_brazil80 = fifa_brazil.loc[(fifa_brazil['OVA'] > 80)]
fifa_brazil_CM = fifa_brazil80.loc[(fifa_brazil80['Position'] == 'CM')]

# %%
fifa_brazil_CM
# Out:
#           ID    Name  Age  OVA Nationality      Club  BOV   BP Position  \
# 3601  199914   Allan   29   83      Brazil   Everton   85  CDM       CM
# 9059  230658  Arthur   23   84      Brazil  Juventus   86   CM       CM
#
#                                            Player Photo  ...    CDM    RDM  \
# 3601  https://cdn.sofifa.com/players/199/914/20_120.png  ...  85+-2  85+-2
# 9059  https://cdn.sofifa.com/players/230/658/20_120.png  ...   81+2   81+2
#
#        RWB    LB   LCB    CB   RCB    RB    GK Gender
# 3601  83+0  83+0  82+1  82+1  82+1  83+0  18+2   Male
# 9059  78+2  76+2  74+2  74+2  74+2  76+2  19+2   Male
#
# [2 rows x 107 columns]

# %% [markdown]
# Brazil also dont have a lot of creative general, from data already stated that facts.

# %%
fifa21_data
# Out:
#            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# 2      Coventry City   71  CAM  CAM RM RW LM
# ...

# %%
fifa_position = fifa21_data['Position'].unique() #returns a list of unique values

# %%
fifa_position
# Out:
# array(['LM', 'CM CAM CDM', 'CAM RM RW LM', nan, 'CM CAM', 'RW RM',
#        'CM CDM', 'LM CM CAM', 'RB CB RWB', 'CDM CM RB', 'CM RM', 'ST',
#        'GK', 'CDM LB LM', 'RM RB CM', 'ST CAM', 'CB', 'RM', 'CF ST',
#        'CAM', 'CDM CM', 'CF ST CAM LW', 'LB', 'LM ST', 'CM RM RB',
#        'LM CAM', 'CDM CM RM', 'CM', 'RB', 'ST CF', 'CM CDM CAM', 'RW',
#        'CM CDM LM CAM', 'LWB LM LB LW', 'CF', 'CAM CM RM', 'RM CAM',
#        'LM CAM RM', 'ST CF RW', 'CDM CM RM RWB', 'CM CDM ST', 'CAM CM',
#        'RM LM', 'CAM LM', 'ST LW', 'CDM', 'CF CAM ST', 'CB CDM', 'CAM ST',
#        'CAM LB', 'CM CAM RM CDM', 'CAM CF RW', 'CAM RW', 'LM RM',
#        'CAM LW', 'CF ST CAM', 'CB LB', 'CAM ST CM', 'RM LM CDM',
#        'LM RM ST', 'LB LM CM', 'RM RW', 'CDM CAM', 'CAM LM RM',
#        'LW LM ST', 'CF ST RW CAM', 'CAM RM LM ST', 'ST CAM LM',
#        'ST CF CAM', 'RB CDM CM', 'RB CM', 'CDM CB', 'CAM CF', 'CB RB',
#        'LW CAM', 'ST RW', 'ST LM', 'CM RB LB', 'LB LWB', 'LW RW', 'RB LB',
# ...

# %%
fifa_brazil80 = fifa_brazil.loc[(fifa_brazil['OVA'] > 80)]
fifa_brazil_CM = fifa_brazil80.loc[(fifa_brazil80['Position'] == 'CM CAM CDM')]

# %%
fifa_brazil_CM
# Out:
#           ID      Name  Age  OVA Nationality                            Club  \
# 2215  187961  Paulinho   31   83      Brazil  Guangzhou Evergrande Taobao FC
#
#       BOV  BP    Position                                       Player Photo  \
# 2215   83  CM  CM CAM CDM  https://cdn.sofifa.com/players/187/961/20_120.png
#
#       ...   CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK Gender
# 2215  ...  81+2  81+2  79+3  79+3  81+2  81+2  81+2  79+3  19+3   Male
#
# [1 rows x 107 columns]

# %% [markdown]
# Paulinho is the only player from Brazil that can play in a variable position at the center and manage to keep his rating more than 80.
#
# This is a kind of player that we want from Brazil that can contribute in different space of football.
#
# Now after this, we will try to see how goods player from Brazil under 25 years old.

# %%
fifa_brazil_25 = fifa21_data.loc[(fifa21_data['Age'] < 25 )]

# %%
fifa_brazil_25 = fifa_brazil_25.loc[(fifa_brazil_25['Nationality'] == 'Brazil')]
fifa_brazil_25
# Out:
#            ID               Name  Age  OVA Nationality              Club  BOV  \
# 793    159169   Anderson Martins   22   71      Brazil     Vasco da Gama   71
# 1326   175792              Elvis   20   66      Brazil   União de Leiria   66
# 1807   183303        Vasconcelos   19   57      Brazil  América de Natal   57
# 2236   188133         Wellington   24   73      Brazil     Internacional   73
# 2537   190232     Fellipe Bastos   23   69      Brazil       Ponte Preta   69
# ...       ...                ...  ...  ...         ...               ...  ...
# 16945  258648     Carlos Augusto   21   66      Brazil          AC Monza   67
# 17006  258783  Guilherme Mantuan   22   65      Brazil    Gil Vicente FC   66
# 17047  258889             Nathan   18   63      Brazil       Boavista FC   63
# 17078  258951         Casagrande   21   65      Brazil   Portimonense SC   67
# 17113  259075          Yan Couto   18   64      Brazil         Girona FC   65
#
# ...

# %% [markdown]
# There are too many Brazil player below 25 years old. So i think we make it more better by sort using rating and we can see how player grow vs age.

# %%
fifa_brazil_25.sort_values('OVA')
# Out:
#            ID              Name  Age  OVA Nationality                    Club  \
# 13674  246447   Nicolas Firmino   18   52      Brazil  New England Revolution
# 12786  243750  Gianluca Zanette   21   54      Brazil          Vejle Boldklub
# 16394  256978        Yago Gomes   18   54      Brazil                FC Vaduz
# 14046  247622     Bernardo Rosa   19   55      Brazil         West Ham United
# 16833  258362           Phelipe   21   56      Brazil               FC Dallas
# ...       ...               ...  ...  ...         ...                     ...
# 9731   233419          Raphinha   23   81      Brazil        Stade Rennais FC
# 5775   212823   Gabriel Barbosa   22   81      Brazil                   Inter
# 7281   222737            Malcom   21   82      Brazil            FC Barcelona
# 9061   230666     Gabriel Jesus   23   83      Brazil         Manchester City
# 9059   230658            Arthur   23   84      Brazil                Juventus
#
# ...

# %%
sns.lineplot(data=fifa_brazil_25, x= 'OVA', y= 'Age', label= 'Age vs OVA for Brazil under 25')
# Out:
# <AxesSubplot:xlabel='OVA', ylabel='Age'>

# %%
fifa_brazil_25_age18 = np.count_nonzero((fifa_brazil_25['Age'] == 18))
fifa_brazil_25_age18
# Out:
# 9

# %%
fifa_brazil_25_age19 = np.count_nonzero((fifa_brazil_25['Age'] == 19))
fifa_brazil_25_age19
# Out:
# 22

# %%
fifa_brazil_25_age20 = np.count_nonzero((fifa_brazil_25['Age'] == 20))
fifa_brazil_25_age20
# Out:
# 83

# %%
fifa_brazil_25_age21 = np.count_nonzero((fifa_brazil_25['Age'] == 21))
fifa_brazil_25_age21
# Out:
# 39

# %% [markdown]
# Many things we can learn from this dataset and we just only at beginning. The only data that we analyst is just for Brazil team and we found so many interesting things.
#
# Next analyst will be more interesting and i will try my best to build machine learning for next project.
#
# Thanks all and please upvote me if you find it interesting.
